# %%
def leiaint(msg):
    ok = False
    valor = 0
    while True:
        
        number = str(input(msg))
        if number.isnumeric():
            valor = int(number)
            ok = True
        else:
            print("\033[0;31mErro!! Digite um valor inteiro valido. \033[m")
        if ok:
            break
    return valor
entrada = leiaint("Digite um numero: !")

print(f"Você digitou o valor : {entrada}")

# %%
def leiaintnovo_int(msg):
    valor = 0
    while True:
        try:
            valor = int(input(msg))
            return valor
            
        except ValueError:
            print("\033[0;31mErro!! Digite um valor inteiro valido. \033[m")
            

  
entrada = leiaintnovo_int("Digite um valor")   
print(f" Valor digitado {entrada}")
# Out:
#  Valor digitado 2

# %% [markdown]
# ____

# %% [markdown]
# ### Acessar site

# %%
from urllib.request import urlopen
with urlopen("https://github.com/pedroita") as response:
    body = response.read()
print(body)
# Out:
# b'\n\n<!DOCTYPE html>\n<html\n  lang="en"\n  \n  data-color-mode="auto" data-light-theme="light" data-dark-theme="dark"\n  data-a11y-animated-images="system" data-a11y-link-underlines="true"\n  >\n\n\n\n\n  <head>\n    <meta charset="utf-8">\n  <link rel="dns-prefetch" href="https://github.githubassets.com">\n  <link rel="dns-prefetch" href="https://avatars.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">\n  <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">\n  <link rel="preconnect" href="https://github.githubassets.com" crossorigin>\n  <link rel="preconnect" href="https://avatars.githubusercontent.com">\n\n  \n\n  <link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/light-0eace2597ca3.css" /><link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/dark-a167e256da9c.css" /><link data-color-theme="dark_dimmed" cros
# ...
